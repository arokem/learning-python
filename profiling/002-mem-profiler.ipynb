# %%
# %load_ext memory_profiler

# %%
import fib

# %%
# %memit fib.fib(10)
# %memit fib.fib(100)
# %memit fib.fib(1000)
# %memit fib.fib(10000)
# Out:
# /Users/arokem/anaconda3/envs/clab/lib/python3.4/site-packages/memory_profiler.py:68: UserWarning: psutil module not found. memory_profiler will be slow
#   warnings.warn("psutil module not found. memory_profiler will be slow")
# /Users/arokem/anaconda3/envs/clab/lib/python3.4/site-packages/memory_profiler.py:68: UserWarning: psutil module not found. memory_profiler will be slow
#   warnings.warn("psutil module not found. memory_profiler will be slow")
# /Users/arokem/anaconda3/envs/clab/lib/python3.4/site-packages/memory_profiler.py:68: UserWarning: psutil module not found. memory_profiler will be slow
#   warnings.warn("psutil module not found. memory_profiler will be slow")
# /Users/arokem/anaconda3/envs/clab/lib/python3.4/site-packages/memory_profiler.py:68: UserWarning: psutil module not found. memory_profiler will be slow
#   warnings.warn("psutil module not found. memory_profiler will be slow")
# ...
